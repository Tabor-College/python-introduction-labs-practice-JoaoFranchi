# %%
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %% [markdown]
# What prints first? What prints last?
#
# prediction = A,C
#
# answer= A,C

# %%
x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %% [markdown]
# What number is printed?
#
# prediction = 10
#
# answer = 10

# %%
x = 5
x = x + 1
print(x)
# Out:
# 6

# %% [markdown]
# What i printed?
#
# prediction = 6
#
# answer = 6

# %%
def add(a,b):
  print("inside")
  return a + b

print("before")
add(2,3)
print("after")
# Out:
# before
# inside
# after

# %% [markdown]
# In what order do the words print?
#
# prediction = before inside after
#
# answer = before inside after

# %%
def make():
  x = [1,2]
  return x

lst = make()
print(lst)
# Out:
# [1, 2]

# %% [markdown]
# Does this print something or crash?
#
# prediction = Will print something
#
# answer = Printed something

# %%
lst = [1,2]
lst.append(3)
print(lst)

lst = [1,2]
lst = [9,10]
print(lst)
# Out:
# [1, 2, 3]
# [9, 10]

# %% [markdown]
# What prints in each case?
#
# predicition = first [1,2,3], second [9,10]
#
# answer = [1,2,3], [9,10]

# %%
def f(x):
  x = x + 1

a = 10
f(a)
print(a)
# Out:
# 10

# %% [markdown]
# What number prints?
#
# prediction = 10
#
# answer = 10

# %%
for i in [1,2,3]:
  print(i)
# Out:
# 1
# 2
# 3

# %% [markdown]
# How many lines print?
#
# prediction = 1
#
# answer = 3

# %%
it = iter([1,2])
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-10269813.py in <cell line: 0>()
#       2 print(next(it))
#       3 print(next(it))
# ----> 4 print(next(it))
#
# StopIteration:

# %% [markdown]
# Does the line print a value or cause an error?
#
# prediction = error
#
# answer = error

# %%
def demo():
  print("A")
  yield 1
  print("B")

x = demo()

# %% [markdown]
# Is anything printed yet?
#
# predition = No
#
# answer = No

# %%
g = demo()
print(next(g))
# Out:
# A
# 1

# %% [markdown]
# Wich letters print, and in what order?
#
# prediction = A then B
#
# answer = A, 1, then B

# %%
def outer():
  x = 10
  def inner():
    return x
  return inner

f = outer()
print(f())
# Out:
# 10

# %% [markdown]
# Does this print a number or crash?
#
# prediction = crash
#
# answer = printed 10

# %%
def deco(fn):
  def wrapper():
    print("before")
    fn()
    print("after")
  return wrapper

@deco
def hello():
  print("hello")

hello()
# Out:
# before
# hello
# after

# %% [markdown]
# How many lines print?
#
# prediction = 3
#
# answer = 3

# %%
class A:
  x = 10

a = A()
print(a.x)
# Out:
# 10

# %% [markdown]
# Does this print a number or raise an error?
#
# prediction = error
#
# answer = prints 10

# %%
class MyRange:
  def __iter__(self):
    return self
  def __next__(self):
    raise StopIteration

  for x in MyRange():
    print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2851064566.py in <cell line: 0>()
# ----> 1 class MyRange:
#       2   def __iter__(self):
#       3     return self
#       4   def __next__(self):
#       5     raise StopIteration
#
# /tmp/ipython-input-2851064566.py in MyRange()
#       5     raise StopIteration
#       6
# ----> 7   for x in MyRange():
#       8     print(x)
#
# NameError: name 'MyRange' is not defined

# %% [markdown]
# Does this run or rash?
#
# prediction = run
#
# answer = crash

# %% [markdown]
# What surprised or confused you the most in the exercise?
#
# I tought I would be able to identify more times when things would work or not I missed almost every time in those questions, but I had some good predictions for most of the questions.
