# %% [markdown]
# Song -- Encapsulation

# %%
class Song:
  total_songs = 0
  def __init__(self, song_id, title, artist, duration):
    self.__song_id = song_id
    self.__title = title
    self.__artist = artist
    self.__duration = duration
    self.__play_count = 0

    Song.total_songs += 1

  def get_title(self):
    return self.__title

  def get_artist(self):
    return self.__artist

  def set_duration(self, new_duration):
    if new_duration > 0:
      self.__duration = new_duration
      return True
    print("Duration must be positive!")
    return False

  def __increment_plays(self):
    self.__play_count += 1

  def play(self):
    self.__increment_plays()
    print(f"Playing:{self.__title} (Plays: {self.__play_count})")

  @staticmethod
  def get_total_songs():
    return Song.total_songs

# %% [markdown]
# Playlist -- Object Composition

# %%
class Playlist:
  def __init__(self, name, creator):
    self.__name = name
    self.__creator = creator
    self.__songs = []

  def add_songs(self, song):
    self.__songs.append(song)
    print(f"{song.get_title()} added to {self.__name}")

  def display(self):
    print(f"\nPlaylist: {self.__name}")
    for i, song in enumerate(self.__songs,1):
      print(f"{i}. {song.get_title()} - {song.get_artist()}")

# %% [markdown]
# User -- Encapsulation + Compostion

# %%
class User:
  total_users = 0

  def __init__(self, username, email, balance):
    self.username = username
    self.email = email
    self.__balance = balance # Changed to private for consistency with pay_for_premium
    self.playlists = []

    User.total_users += 1

  def pay_for_premium(self, cost):
    if cost <= self.__balance:
      self.__balance -= cost
      print("Premium activated!")
      return True
    print("Insufficient balance!")
    return False

  def create_playlist(self, name):
    playlist = Playlist(name, self.username)
    self.playlists.append(playlist)
    return playlist

  @staticmethod
  def get_total_users():
    return User.total_users

# %% [markdown]
# Object Creation and Execution Flow

# %%
# Create Song objects
song1 = Song (101 , " Blinding Lights " , " The Weeknd " , 200)
song2 = Song (102 , " Shape of You " , " Ed Sheeran " , 234)
print ( " Total Songs : " , Song . get_total_songs () )
# Play a song
song1 . play ()
song1 . play ()
# Create User
user1 = User ( " Amar " , " amar@spotify . com " , 500)
# Create Playlist
favorites = user1 . create_playlist ( " My Favorites " )
# Add Song objects to Playlist
favorites . add_songs ( song1 )
favorites . add_songs ( song2 )
# Display Playlist
favorites . display ()
# Pay for premium
user1 . pay_for_premium (200)
# Out:
#  Total Songs :  2
# Playing: Blinding Lights  (Plays: 1)
# Playing: Blinding Lights  (Plays: 2)
#  Blinding Lights  added to  My Favorites
#  Shape of You  added to  My Favorites
#
# Playlist:  My Favorites
# 1.  Blinding Lights  -  The Weeknd
# 2.  Shape of You  -  Ed Sheeran
# Premium activated!
# True

# %% [markdown]
# Song -- Encapsulation + Decorator

# %%
def playback_logger(func):
  """ DECORATOR: Adds logging around playback"""
  def wrapper(self):
    print("     Logging playback..")
    result = func(self)
    print("     Playback complete\n")
    return result
  return wrapper

class Song:
  total_songs = 0

  def __init__(self,song_id,title,artist, duration):
    self.__song_id = song_id
    self.__title = title
    self.__artist = artist
    self.__duration = duration
    self.__play_count = 0
    Song.total_songs += 1

  def get_title(self):
    return self.__title

  def get_artist(self):
    return self.__artist

  def __increment_plays(self):
    self.__play_count += 1

  @playback_logger
  def play(self):
    self.__increment_plays()
    print(f"Playing: {self.__title} (Plays: {self.__play_count})")

# %% [markdown]
# Playlist -- Iterator,Generator, Duck Typing

# %%
class Playlist:
  def __init__(self,name):
    self.__name = name
    self.songs = []

  def add_song(self, song):
    self.songs.append(song)

  def __iter__(self):
    """ITERATOR ENTRY POINT"""
    self._index = 0
    return self

  def __next__(self):
    """ITERATOR CONTROL"""
    if self._index >= len(self.songs):
      raise StopIteration
    song = self.songs[self._index]
    self._index += 1
    return song

  def play_songs(self):
    """GENERATOR: Yields songs one at a time"""
    for song in self.songs:
      yield song

  def play_all(self, player):
    """
    DUCK TYPING:
    Any object with a play() method works
    """
    for song in self:
      player.play(song)

# %% [markdown]
# Closures -- Stateful Behavior Withou Classes

# %%
def playback_Limiter(max_plays):
  """
  CLOSURE:
  Remembers play count across calls
  """
  count = 0

  def limiter(song):
    nonlocal count
    if count < max_plays:
      song.play()
      count += 1
    else:
      print("     Playback limit reached")
  return limiter

# %% [markdown]
# Duck Typing -- Playback Controllers

# %%
class SimplePlayer:
  def play(self,song):
    song.play()

class LimitedPlayer:
  def __init__(self, limiter):
    self.limiter = limiter

  def play(self,song):
    self.limiter(song)

# %% [markdown]
# Object Creation and Runtime Flow

# %%
s1 = Song(101, "Blinding Lights", "The Weeknd", 200)
s2 = Song(102, "Shape of You", "Ed Sheeran", 234)

favorites = Playlist("My Favorites")
favorites.add_song(s1)
favorites.add_song(s2)

limit_1 = playback_Limiter(1)

normal_player = SimplePlayer()
limited_player = LimitedPlayer(limit_1)

favorites.play_all(normal_player)
favorites.play_all(limited_player)
# Out:
#      Logging playback..
# Playing: Blinding Lights (Plays: 1)
#      Playback complete
#
#      Logging playback..
# Playing: Shape of You (Plays: 1)
#      Playback complete
#
#      Logging playback..
# Playing: Blinding Lights (Plays: 2)
#      Playback complete
#
#      Playback limit reached
