# %%
a = 10
b = a
a = 20
print(b)
# Out:
# 10

# %% [markdown]
# Was the object mutable or immutable?
#
# The object was immutable since you just change what it refers to not the object

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# You rebind it by changing a to 20

# %% [markdown]
# Did the change affect other references?
#
# No the change only affects a

# %%
def f(x):
  x = x +1
  print(x)

n = 5
f(n)
print(n)
# Out:
# 6
# 5

# %% [markdown]
# Was the object mutable or immutable?
#
# Immutable since the variables stayed n the same

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# x is rebounded to 6

# %% [markdown]
# Did the change affect other references?
#
# No n still have the same value at the end

# %%
x = 5
print(id(x))
x += 1
print(id(x))
# Out:
# 11654504
# 11654536

# %% [markdown]
# Was the object mutable or immutable?
#
# imutable because the object x is still x even when you change the inside of it

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# it rebidns x from 5 to 6

# %% [markdown]
# Did the change affect other references?
#
# no in the end the only thing changed is x from 5 to 6

# %%
lst = [1,2]
print(id(lst))
lst.append(3)
print(id(lst))
# Out:
# 139042992523648
# 139042992523648

# %% [markdown]
# Was the object mutable or immutable?
#
# mutable since it is a list and you are adding 3 to it

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# it mutates the object the name is the same but you add something inside of it

# %% [markdown]
# Did the change affect other references?
#
# yes it changes the objects inside the list

# %%
def change(x):
  x = x + 10

a = 5
change(a)
print(a)
# Out:
# 5

# %% [markdown]
# Was the object mutable or immutable?
#
# immutable because it passes inside the def and doesn't change after

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# it rebinds x to 15 but a stays the same

# %% [markdown]
# Did the change affect other references?
#
# no it just changed what x refers to a is still 5

# %%
def change(lst):
  lst.append(99)

data = [1,2]
change(data)
print(data)
# Out:
# [1, 2, 99]

# %% [markdown]
# Was the object mutable or immutable?
#
# mutable you change the values inside the list

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# mutate the object by adding 99 to it

# %% [markdown]
# Did the change affect other references?
#
# yes it changes the list

# %%
def reset_wrong(lst):
  lst = []

def reset_right(lst):
  lst.clear()

data = [1,2,3]
reset_wrong(data)
print(data)

reset_right(data)
print(data)
# Out:
# [1, 2, 3]
# []

# %% [markdown]
# Was the object mutable or immutable?
#
# mutable once you can clean the list

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# it chganged what the list refered to so is a rebind of the name and then it wiped it so it mutate it

# %% [markdown]
# Did the change affect other references?
#
# yes the list was wiped

# %%
def demo(x):
  print(id(x))
  x.append(5)
  print(id(x))

lst = [1,2]
print(id(lst))
demo(lst)
# Out:
# 139042992933440
# 139042992933440
# 139042992933440

# %% [markdown]
# Was the object mutable or immutable?
#
# it was mutable because you append 5 to is adding things to the list

# %% [markdown]
# Did Python mutate the object or rebind the name?
#
# it mutates the object the name is the same but the object is changed in the inside

# %% [markdown]
# Did the change affect other references?
#
# yes it changes the list so even if the name doesn't change the objects inside the list do
